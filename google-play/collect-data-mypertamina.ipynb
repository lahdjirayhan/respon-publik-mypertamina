# %%
# Define various auxiliary helpers and
# design a primary function to scrape

import numpy as np
from google_play_scraper import reviews, app
import time
import logging
import sys

def setup_logger(silent = False):
    """Setup a logger that streams to stdout (not red background on Jupyter)
    
    When used in Kaggle, the output log can be obtained via Log page.
    """
    logger = logging.getLogger("mylog")
    
    if silent:
        logger.setLevel(logging.ERROR)
    else:
        logger.setLevel(logging.DEBUG)
    
    stream_handler = logging.StreamHandler(stream = sys.stdout)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    
    stream_handler.setFormatter(formatter)
    logger.addHandler(stream_handler)
    
    return logger

def scrape(APP_ID, sleep_second = 0.05, max_time = 8.5*3600, silent = False):
    """Scrape reviews on APP_ID
    
    Scrape Google Play Store reviews of application with id APP_ID,
    using language and country tag 'id' (Indonesia).
    
    Every 1000 reviews scraped, add delay time of sleep_second seconds
    to avoid dead responses/bottleneck/blocking.
    
    Halt scraping process when reaches max_time seconds.
    """
    
    logger = setup_logger(silent = silent)
    
    logger.info(f"BEGINNING OF FUNCTION CALL")
    logger.info(f"==================================")
    logger.info(f"Scraping started for: {APP_ID}")
    logger.info(f"Language and country tag is 'id'")
    
    app_info = app(APP_ID, lang = 'id', country = 'id')
    
    logger.info(f'----------------------------------')
    logger.info(f"Information")
    logger.info(f"Name: {app_info['title']}")
    logger.info(f"Enlisted reviews count : {app_info['reviews']}")
    logger.info(f'----------------------------------')
    
    start_time = time.time()
    timeout = start_time + max_time
    
    result, continuation_token = reviews(
        APP_ID, lang = 'id', country = 'id'
    )
    
    _n_prev, _n_current = len(result), len(result)
    logger.info(f"Number of acquired reviews so far: {_n_current}")
    
    # If the .token attribute is not None, it means there's more to scrape.
    while continuation_token.token:
        _result, continuation_token = reviews(
            APP_ID, lang = 'id', country = 'id',
            continuation_token = continuation_token
        )
        
        result += _result
        _n_current = len(result)
        # Update counts every 1000 reviews fetched
        # Deliberately delay requests by sleep_in_seconds seconds on every count update
        if _n_current - _n_prev >= 1000:
            _n_prev = _n_current
            logger.info(f"Number of acquired reviews so far: {_n_current}")
            
            time.sleep(sleep_second)
        
        if time.time() >= timeout:
            logger.warning(f"Timeout reached, escaping loop.")
            break
    
    seconds_elapsed = time.time() - start_time
    minutes_elapsed = np.round(seconds_elapsed/60, 4)
    logger.info(f"Scraping finished after {minutes_elapsed} minutes")
    
    final_count = len(result)
    fraction = np.round(final_count/app_info['reviews'], 4)*100
    
    logger.info(f"Final count of reviews scraped: {final_count}")
    logger.info(f"{fraction}% of enlisted review count.")
    logger.info(f"==================================")
    logger.info(f"END OF FUNCTION CALL")
    
    return result

# %%
# Perform scraping
APP_NAME = 'com.dafturn.mypertamina'
result = scrape(APP_NAME, max_time = 2*3600)
# Out:
# 2022-07-04 17:18:50,992 - mylog - INFO - BEGINNING OF FUNCTION CALL
# 2022-07-04 17:18:51,032 - mylog - INFO - ==================================
# 2022-07-04 17:18:51,042 - mylog - INFO - Scraping started for: com.dafturn.mypertamina
# 2022-07-04 17:18:51,046 - mylog - INFO - Language and country tag is 'id'
# 2022-07-04 17:19:05,022 - mylog - INFO - ----------------------------------
# 2022-07-04 17:19:05,022 - mylog - INFO - Information
# 2022-07-04 17:19:05,022 - mylog - INFO - Name: MyPertamina
# 2022-07-04 17:19:05,022 - mylog - INFO - Enlisted reviews count : 140001
# 2022-07-04 17:19:05,022 - mylog - INFO - ----------------------------------
# 2022-07-04 17:19:08,866 - mylog - INFO - Number of acquired reviews so far: 100
# 2022-07-04 17:19:28,125 - mylog - INFO - Number of acquired reviews so far: 1100
# 2022-07-04 17:20:11,197 - mylog - INFO - Number of acquired reviews so far: 2100
# 2022-07-04 17:20:26,085 - mylog - INFO - Number of acquired reviews so far: 3100
# 2022-07-04 17:20:49,115 - mylog - INFO - Number of acquired reviews so far: 4100
# 2022-07-04 17:21:13,357 - mylog - INFO - Number of acquired reviews so far: 5100
# 2022-07-04 17:21:25,871 - mylog - INFO - Number of acquired reviews so far: 6100
# 2022-07-04 17:21:37,225 - mylog - INFO - Number of acquired reviews so far: 7100
# 2022-07-04 17:21:51,757 - mylog - INFO - Number of acquired reviews so far: 8100
# 2022-07-04 17:22:17,057 - mylog - INFO - Number of acquired reviews so far: 9100
# 2022-07-04 17:22:48,117 - mylog - INFO - Number of acquired reviews so far: 10100
# 2022-07-04 17:23:19,993 - mylog - INFO - Number of acquired reviews so far: 11100
# 2022-07-04 17:23:33,497 - mylog - INFO - Number of acquired reviews so far: 12100
# 2022-07-04 17:23:56,109 - mylog - INFO - Number of acquired reviews so far: 13100
# 2022-07-04 17:24:12,883 - mylog - INFO - Number of acquired reviews so far: 14100
# 2022-07-04 17:24:29,347 - mylog - INFO - Number of acquired reviews so far: 15100
# 2022-07-04 17:24:43,731 - mylog - INFO - Number of acquired reviews so far: 16100
# 2022-07-04 17:25:02,437 - mylog - INFO - Number of acquired reviews so far: 17100
# 2022-07-04 17:25:21,041 - mylog - INFO - Number of acquired reviews so far: 18100
# 2022-07-04 17:25:41,609 - mylog - INFO - Number of acquired reviews so far: 19100
# 2022-07-04 17:25:54,807 - mylog - INFO - Number of acquired reviews so far: 20100
# 2022-07-04 17:26:20,386 - mylog - INFO - Number of acquired reviews so far: 21100
# 2022-07-04 17:26:40,312 - mylog - INFO - Number of acquired reviews so far: 22100
# 2022-07-04 17:26:57,098 - mylog - INFO - Number of acquired reviews so far: 23100
# 2022-07-04 17:27:13,648 - mylog - INFO - Number of acquired reviews so far: 24100
# 2022-07-04 17:27:31,878 - mylog - INFO - Number of acquired reviews so far: 25100
# 2022-07-04 17:27:50,186 - mylog - INFO - Number of acquired reviews so far: 26100
# 2022-07-04 17:28:05,580 - mylog - INFO - Number of acquired reviews so far: 27100
# 2022-07-04 17:28:29,485 - mylog - INFO - Number of acquired reviews so far: 28100
# 2022-07-04 17:28:45,425 - mylog - INFO - Number of acquired reviews so far: 29100
# 2022-07-04 17:28:58,217 - mylog - INFO - Number of acquired reviews so far: 30100
# 2022-07-04 17:29:27,933 - mylog - INFO - Number of acquired reviews so far: 31100
# 2022-07-04 17:29:52,802 - mylog - INFO - Number of acquired reviews so far: 32100
# 2022-07-04 17:30:05,411 - mylog - INFO - Number of acquired reviews so far: 33100
# 2022-07-04 17:30:18,331 - mylog - INFO - Number of acquired reviews so far: 34100
# 2022-07-04 17:30:41,375 - mylog - INFO - Number of acquired reviews so far: 35100
# 2022-07-04 17:30:55,721 - mylog - INFO - Number of acquired reviews so far: 36100
# 2022-07-04 17:31:13,061 - mylog - INFO - Number of acquired reviews so far: 37100
# 2022-07-04 17:31:29,601 - mylog - INFO - Number of acquired reviews so far: 38100
# 2022-07-04 17:31:46,155 - mylog - INFO - Number of acquired reviews so far: 39100
# 2022-07-04 17:31:59,267 - mylog - INFO - Number of acquired reviews so far: 40100
# 2022-07-04 17:32:12,929 - mylog - INFO - Number of acquired reviews so far: 41100
# 2022-07-04 17:32:32,193 - mylog - INFO - Number of acquired reviews so far: 42100
# 2022-07-04 17:32:54,814 - mylog - INFO - Number of acquired reviews so far: 43100
# 2022-07-04 17:33:09,838 - mylog - INFO - Number of acquired reviews so far: 44100
# 2022-07-04 17:33:32,862 - mylog - INFO - Number of acquired reviews so far: 45100
# 2022-07-04 17:34:13,926 - mylog - INFO - Number of acquired reviews so far: 46100
# 2022-07-04 17:34:33,546 - mylog - INFO - Number of acquired reviews so far: 47100
# 2022-07-04 17:34:50,054 - mylog - INFO - Number of acquired reviews so far: 48100
# 2022-07-04 17:35:07,832 - mylog - INFO - Number of acquired reviews so far: 49100
# 2022-07-04 17:35:30,906 - mylog - INFO - Number of acquired reviews so far: 50100
# 2022-07-04 17:35:57,472 - mylog - INFO - Number of acquired reviews so far: 51100
# 2022-07-04 17:36:13,004 - mylog - INFO - Number of acquired reviews so far: 52100
# 2022-07-04 17:36:33,272 - mylog - INFO - Number of acquired reviews so far: 53100
# 2022-07-04 17:37:21,242 - mylog - INFO - Number of acquired reviews so far: 54100
# 2022-07-04 17:37:46,902 - mylog - INFO - Number of acquired reviews so far: 55100
# 2022-07-04 17:38:06,905 - mylog - INFO - Number of acquired reviews so far: 56100
# 2022-07-04 17:38:23,093 - mylog - INFO - Number of acquired reviews so far: 57100
# 2022-07-04 17:38:39,079 - mylog - INFO - Number of acquired reviews so far: 58100
# 2022-07-04 17:38:54,795 - mylog - INFO - Number of acquired reviews so far: 59100
# 2022-07-04 17:39:15,727 - mylog - INFO - Number of acquired reviews so far: 60100
# 2022-07-04 17:39:35,047 - mylog - INFO - Number of acquired reviews so far: 61100
# 2022-07-04 17:39:55,365 - mylog - INFO - Number of acquired reviews so far: 62100
# 2022-07-04 17:40:10,731 - mylog - INFO - Number of acquired reviews so far: 63100
# 2022-07-04 17:40:25,471 - mylog - INFO - Number of acquired reviews so far: 64100
# 2022-07-04 17:40:40,683 - mylog - INFO - Number of acquired reviews so far: 65100
# 2022-07-04 17:41:07,075 - mylog - INFO - Number of acquired reviews so far: 66100
# 2022-07-04 17:41:25,482 - mylog - INFO - Number of acquired reviews so far: 67100
# 2022-07-04 17:41:41,425 - mylog - INFO - Number of acquired reviews so far: 68100
# 2022-07-04 17:41:59,069 - mylog - INFO - Number of acquired reviews so far: 69100
# 2022-07-04 17:42:14,493 - mylog - INFO - Number of acquired reviews so far: 70100
# 2022-07-04 17:42:32,313 - mylog - INFO - Number of acquired reviews so far: 71100
# 2022-07-04 17:42:50,013 - mylog - INFO - Number of acquired reviews so far: 72100
# 2022-07-04 17:43:05,779 - mylog - INFO - Number of acquired reviews so far: 73100
# 2022-07-04 17:43:21,597 - mylog - INFO - Number of acquired reviews so far: 74100
# 2022-07-04 17:43:37,041 - mylog - INFO - Number of acquired reviews so far: 75100
# 2022-07-04 17:43:55,919 - mylog - INFO - Number of acquired reviews so far: 76100
# 2022-07-04 17:44:19,917 - mylog - INFO - Number of acquired reviews so far: 77100
# 2022-07-04 17:44:55,571 - mylog - INFO - Number of acquired reviews so far: 78100
# 2022-07-04 17:45:18,041 - mylog - INFO - Number of acquired reviews so far: 79100
# 2022-07-04 17:45:39,531 - mylog - INFO - Number of acquired reviews so far: 80100
# 2022-07-04 17:46:03,223 - mylog - INFO - Number of acquired reviews so far: 81100
# 2022-07-04 17:46:17,773 - mylog - INFO - Number of acquired reviews so far: 82100
# 2022-07-04 17:46:32,463 - mylog - INFO - Number of acquired reviews so far: 83100
# 2022-07-04 17:46:49,920 - mylog - INFO - Number of acquired reviews so far: 84100
# 2022-07-04 17:47:51,678 - mylog - INFO - Number of acquired reviews so far: 85100
# 2022-07-04 17:48:10,102 - mylog - INFO - Number of acquired reviews so far: 86100
# 2022-07-04 17:48:29,750 - mylog - INFO - Number of acquired reviews so far: 87100
# 2022-07-04 17:48:43,936 - mylog - INFO - Number of acquired reviews so far: 88100
# 2022-07-04 17:48:57,668 - mylog - INFO - Number of acquired reviews so far: 89100
# 2022-07-04 17:49:15,500 - mylog - INFO - Number of acquired reviews so far: 90100
# 2022-07-04 17:49:33,068 - mylog - INFO - Number of acquired reviews so far: 91100
# 2022-07-04 17:49:46,894 - mylog - INFO - Number of acquired reviews so far: 92100
# 2022-07-04 17:50:03,794 - mylog - INFO - Number of acquired reviews so far: 93100
# 2022-07-04 17:50:18,204 - mylog - INFO - Number of acquired reviews so far: 94100
# 2022-07-04 17:50:31,948 - mylog - INFO - Number of acquired reviews so far: 95100
# 2022-07-04 17:50:48,694 - mylog - INFO - Number of acquired reviews so far: 96100
# 2022-07-04 17:51:12,136 - mylog - INFO - Number of acquired reviews so far: 97100
# 2022-07-04 17:51:33,121 - mylog - INFO - Number of acquired reviews so far: 98100
# 2022-07-04 17:51:47,555 - mylog - INFO - Number of acquired reviews so far: 99100
# 2022-07-04 17:52:02,917 - mylog - INFO - Number of acquired reviews so far: 100100
# 2022-07-04 17:52:18,417 - mylog - INFO - Number of acquired reviews so far: 101100
# 2022-07-04 17:52:36,869 - mylog - INFO - Number of acquired reviews so far: 102100
# 2022-07-04 17:52:55,131 - mylog - INFO - Number of acquired reviews so far: 103100
# 2022-07-04 17:53:10,758 - mylog - INFO - Number of acquired reviews so far: 104100
# 2022-07-04 17:53:26,398 - mylog - INFO - Number of acquired reviews so far: 105100
# 2022-07-04 17:53:41,970 - mylog - INFO - Number of acquired reviews so far: 106100
# 2022-07-04 17:54:02,386 - mylog - INFO - Number of acquired reviews so far: 107100
# 2022-07-04 17:54:20,746 - mylog - INFO - Number of acquired reviews so far: 108100
# 2022-07-04 17:54:37,886 - mylog - INFO - Number of acquired reviews so far: 109100
# 2022-07-04 17:55:12,684 - mylog - INFO - Number of acquired reviews so far: 110100
# 2022-07-04 17:55:48,258 - mylog - INFO - Number of acquired reviews so far: 111100
# 2022-07-04 17:56:15,112 - mylog - INFO - Number of acquired reviews so far: 112100
# 2022-07-04 17:56:35,256 - mylog - INFO - Number of acquired reviews so far: 113100
# 2022-07-04 17:57:07,459 - mylog - INFO - Number of acquired reviews so far: 114100
# 2022-07-04 17:57:38,393 - mylog - INFO - Number of acquired reviews so far: 115100
# 2022-07-04 17:58:05,695 - mylog - INFO - Number of acquired reviews so far: 116100
# 2022-07-04 17:58:26,893 - mylog - INFO - Number of acquired reviews so far: 117100
# 2022-07-04 17:58:50,479 - mylog - INFO - Number of acquired reviews so far: 118100
# 2022-07-04 17:59:21,009 - mylog - INFO - Number of acquired reviews so far: 119100
# 2022-07-04 17:59:51,433 - mylog - INFO - Number of acquired reviews so far: 120100
# 2022-07-04 18:00:42,072 - mylog - INFO - Number of acquired reviews so far: 121100
# 2022-07-04 18:01:17,876 - mylog - INFO - Number of acquired reviews so far: 122100
# 2022-07-04 18:01:40,014 - mylog - INFO - Scraping finished after 42.5822 minutes
# 2022-07-04 18:01:40,024 - mylog - INFO - Final count of reviews scraped: 122994
# 2022-07-04 18:01:40,024 - mylog - INFO - 87.85% of enlisted review count.
# 2022-07-04 18:01:40,024 - mylog - INFO - ==================================
# 2022-07-04 18:01:40,034 - mylog - INFO - END OF FUNCTION CALL

# %%
# Turn the resulting list of dictionary (json format)
# into pandas dataframe.
import pandas as pd
raw_df = pd.json_normalize(result)

# Drop the user image column, it will never be used.
# Other columns may be useful. But who knows.
result_df = raw_df.drop(['userImage'], axis = 1).copy()

# Get indexes for latest version
# idx_latest_ver = result_df[result_df['reviewCreatedVersion'] == '4.0.2'].index

# Take latest version
# result_df = result_df.loc[idx_latest_ver, :]

# Show dataframe
result_df
# Out:
#                                     reviewId               userName  \
# 0       e3ec75ec-675b-4328-bed5-e2f3dbfe0a91            Radhy Aiman
# 1       a6923e84-bef9-4c86-8b88-ae6b8d98940b             rara mulan
# 2       384c929f-6554-4723-bf83-355656281321  Indramayu TV Official
# 3       c96d5d1d-3c2f-408b-8f42-2cf2c3e411ea           M.fahri29 29
# 4       512d0b16-8fd4-42b4-b648-6b22c28bc422            Soko Hengky
# ...                                      ...                    ...
# 122989  273b017d-1b0a-4b8a-961a-faa7629f40f2        Pengguna Google
# 122990  7c86bfc3-7d7f-425d-98d9-bde583f2f6d9        Pengguna Google
# 122991  45e977af-e705-4d02-9ad4-4c3d357e0b1a        Pengguna Google
# 122992  592690d7-ecdb-4796-ae06-6764c70b3840        Pengguna Google
# 122993  9185aeed-b46a-42b7-87f4-4c4380f8b09a        Pengguna Google
#
#                                                   content  score  \
# 0                      Ini salah masa buka hp dipertamina      1
# 1                          Mau menyusahkan rakyat ya....?      1
# 2       Sering nge bug, dan grafiknya juga buriq kayak...      1
# 3                                                      Uh      1
# 4                                                   Ribet      1
# ...                                                   ...    ...
# 122989                                          Mantap...      5
# 122990     #bringbackRioHaryantoF12018 @pertaminaracingid      3
# 122991  Downloader ke 100... Nice apps... smg ada prog...      5
# 122992  Good start.. be responsive toward feedback and...      5
# 122993  Saya kasih bintang 3 dolo yee...soalnya blom c...      3
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                   0                3.6.2 2022-07-04 17:18:54
# 1                   0                3.6.2 2022-07-04 17:18:51
# 2                   0                3.6.2 2022-07-04 17:18:50
# 3                   0                3.6.2 2022-07-04 17:18:44
# 4                   0                3.6.2 2022-07-04 17:18:36
# ...               ...                  ...                 ...
# 122989              1                 None 2017-08-10 21:19:14
# 122990              0                 None 2017-08-10 09:50:30
# 122991              1                1.0.2 2017-08-10 08:43:30
# 122992              0                  1.0 2017-08-09 17:58:21
# 122993              1                  1.0 2017-08-09 13:18:30
#
#                                              replyContent           repliedAt
# 0                                                    None                 NaT
# 1                                                    None                 NaT
# 2                                                    None                 NaT
# 3                                                    None                 NaT
# 4                                                    None                 NaT
# ...                                                   ...                 ...
# 122989  Terima kasih sobat Sukrons KRN atas apresiasin... 2018-09-14 13:13:14
# 122990  Terima kasih atas masukannya sobat bukhari yul... 2018-09-17 04:29:16
# 122991  Terima kasih sobat Dudy Effendi atas attention... 2018-09-14 13:06:49
# 122992  Hai sobat Ilmianto Boediman. Terima kasih atas... 2018-10-03 15:03:26
# 122993  Terima kasih sobat Indrie Lestari atas attenti... 2018-09-17 08:38:33
#
# [122994 rows x 9 columns]

# %%
# Save to csv, the most loved format by data scientists
result_df.to_csv('mypertamina-review.csv', index=False)
